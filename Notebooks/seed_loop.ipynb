# %%
import os 
cwd = os.getcwd()

os.chdir('../')
cwd = os.getcwd()
print(cwd)

os.chdir('./code/')
cwd = os.getcwd()
print(cwd)

import pandas as pd 
import numpy as np 
import seaborn as sns

import pickle 
import logging


# from config.config import SQLQuery
# querySno = SQLQuery('snowflake')
# Out:
# /Users/shashankgupta/Documents/code/git_project/plaid_credit
# /Users/shashankgupta/Documents/code/git_project/plaid_credit/Code

# %%
from preprocess import Convert,MissingValues,Outlier,FeatureSelection
from feature_transformation import Scaler,Transform,Selection
from model_building import split_test_train, feature_encoding, classification_models
from model_evaluations import model_metrics, feature_importance, probability_bins, cross_validation
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, Normalizer

from statsmodels.stats.outliers_influence import variance_inflation_factor

# object initiation 
tf = Transform()
sel = Selection()
ft = FeatureSelection()
cv = Convert()
mv = MissingValues()
ot = Outlier()

# set seed
# seed = 1

# %%
corr_arr = 0.5 # person correlation coefficient # change it to 0.5
vif_arr = 5 # vif coefficient
features_arr = 10 # total number of features to be selected from backward feature selection
iv_upper_limit = 0.5 # upper threshold of iv # change it to 0.6
iv_lower_limit = 0.02 # lower threshold of iv

# %%
df_raw = pd.read_pickle('/Users/shashankgupta/Documents/code/git_project/plaid_credit/data/final_dataset_2.pkl')
df_raw.shape
# Out:
# (646, 255)

# %%
# excluding stddev features
keep_stddev_cols = ['stddev_credit_amt_3M']
stddev_cols = list(df_raw.loc[:,df_raw.columns.str.contains('stddev')].columns)

keep_cols = list(set(list(df_raw.columns)).difference(set(stddev_cols))) + keep_stddev_cols


df_raw = df_raw[keep_cols]
df_raw.shape
# Out:
# (646, 219)

# %%
df_raw['txn_flag'].value_counts()
# Out:
# txn_flag
# 1.0    637
# 0.0      9
# Name: count, dtype: int64

# %%
df_raw = df_raw[df_raw['txn_flag']==1]
df_raw.shape
# Out:
# (637, 219)

# %%
df_raw = df_raw.drop(['business_id', 'lending_business_id','decision_date','drawn_flag', 'everDPD_15', 'fico_score','txn_flag'], axis=1)
df_raw.shape
# Out:
# (637, 212)

# %%
# get constant features
def get_const_features(df):
    const_list = []
    for col in df.columns: 
        if (len(df[col].unique())==1):
            const_list.append(col)
    return(const_list)

# get quasi-constant features
def get_quasi_const_features(df, threshold=0.01):
    qconst_list = []
    for col in df.columns: 
        if (df[col].var() <= threshold):
            qconst_list.append(col)
    return(qconst_list)

# view missing values
def missing_value(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_val_df = pd.DataFrame({'percent_missing': percent_missing})
    missing_val_df.sort_values(by='percent_missing', ascending=False, inplace=True)
    return missing_val_df

# get boolean columns
def findbool(df):
    bool_arr = []
    for col in df.columns: 
        if (len(df[col].unique())<=2):
            bool_arr.append(col)
    return(bool_arr)

# get datatypes frequency
def get_datatypes_freq(df):
    type_dct = {str(k): list(v) for k, v in df.groupby(df.dtypes, axis=1)}
    type_dct_info = {k: len(v) for k, v in type_dct.items()}
    return type_dct, type_dct_info

## iv_woe

def iv_woe(data, target, bins=10, show_woe=False):
    
    #Empty Dataframe
    newDF,woeDF = pd.DataFrame(), pd.DataFrame()
    
    #Extract Column Names
    cols = data.columns
    
    #Run WOE and IV on all the independent variables
    for ivars in cols[~cols.isin([target])]:
        if (data[ivars].dtype.kind in 'bifc') and (len(np.unique(data[ivars]))>10):
            binned_x = pd.qcut(data[ivars], bins,  duplicates='drop')
            d0 = pd.DataFrame({'x': binned_x, 'y': data[target]})
        else:
            d0 = pd.DataFrame({'x': data[ivars], 'y': data[target]})

        
        # Calculate the number of events in each group (bin)
        d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
        d.columns = ['Cutoff', 'N', 'Events']
        
        # Calculate % of events in each group.
        d['% of Events'] = np.maximum(d['Events'], 0.5) / d['Events'].sum()

        # Calculate the non events in each group.
        d['Non-Events'] = d['N'] - d['Events']
        # Calculate % of non events in each group.
        d['% of Non-Events'] = np.maximum(d['Non-Events'], 0.5) / d['Non-Events'].sum()

        # Calculate WOE by taking natural log of division of % of non-events and % of events
        d['WoE'] = np.log(d['% of Events']/d['% of Non-Events'])
        d['IV'] = d['WoE'] * (d['% of Events'] - d['% of Non-Events'])
        d.insert(loc=0, column='Variable', value=ivars)
        print("Information value of " + ivars + " is " + str(round(d['IV'].sum(),6)))
        temp =pd.DataFrame({"Variable" : [ivars], "IV" : [d['IV'].sum()]}, columns = ["Variable", "IV"])
        newDF=pd.concat([newDF,temp], axis=0)
        woeDF=pd.concat([woeDF,d], axis=0)

        #Show WOE Table
        if show_woe == True:
            print(d)
    return newDF, woeDF


# get feature list after iterative VIF elimination
def vif_iter(df, iv, threshold=10):
    vif_data = pd.DataFrame()
    vif_data["feature"] = iv
    vif_data["VIF"] = [variance_inflation_factor(df[iv].values, i) for i in range(len(iv))]
    if len(vif_data[vif_data['VIF'] == np.inf]) > 0:
        feature = vif_data[vif_data['VIF'] == np.inf]['feature'].iloc[0]
        iv.remove(feature)
        vif_iter(df, iv, threshold)
    elif len(vif_data[vif_data['VIF'] > threshold]) > 0:
        feature = vif_data.sort_values(by='VIF', ascending=False)['feature'].iloc[0]
        iv.remove(feature)
        vif_iter(df, iv, threshold)
    vif_data = pd.DataFrame()
    vif_data["feature"] = iv
    vif_data["VIF"] = [variance_inflation_factor(df[iv].values, i) for i in range(len(iv))]
    return iv, vif_data

# %%
def main_func(df_raw, corr_arr,vif_arr,features_arr,iv_upper_limit,iv_lower_limit,seed):
    x_train, y_train, x_test, y_test = split_test_train(df_raw, target_column='target', test_size=0.3, random_state=seed)
    print(f'{x_train.shape = }', '|' ,f'{y_train.shape = }', '|' ,f'{x_test.shape = }', '|' ,f'{y_test.shape = }')


    # copy to df
    df = x_train.copy(deep=True)

    const_list = get_const_features(df)
    df = df.drop(columns=const_list)
    
    qconst_list = get_quasi_const_features(df, threshold=0.01)
    df = df.drop(columns=qconst_list)

    #missing values
    df = df.fillna(0)

    type_dct, type_dct_info = get_datatypes_freq(df)
    bool_col_list = findbool(df)
    col_list = (type_dct['float64'])
    col_list_excpt_bool = [column for column in col_list if column not in bool_col_list]
    print('col_list_exc_bool = {}'.format(len(col_list_excpt_bool)))

    df['target'] = y_train
    df['target'] = df['target'].astype(float)
    temp = df.copy()

    t1, t2 = iv_woe(temp[np.append(col_list_excpt_bool,['target'])], 'target', bins=5, show_woe=False)
    feature_list = list(t1[ (t1['IV']<iv_upper_limit) & (t1['IV']>iv_lower_limit) ]['Variable'].values)

    #remove correlated features
    corr_df, subset_df = sel.get_correlated_features(df, feature_list, thresh=corr_arr)
    feature_list = sel.corr_iter(df, np.array(feature_list), thresh=corr_arr)
    feature_list = list(feature_list)

    #vif
    feature_list, vif_df = vif_iter(df, feature_list, threshold=vif_arr)

    #backward feature selection
    feat_list = ft.backward_feature_selection(df[feature_list], y_train, num_features=features_arr)

    return feat_list

# %%
feat_df = pd.DataFrame(df_raw.columns,columns = ['feature_name']) 
feat_df['count'] = 0
feat_df
# Out:
#                                       feature_name  count
# 0                                 service_count_6M      0
# 1                            median_payroll_amt_3M      0
# 2                     ratio_third_party_size_1M_6M      0
# 3    ratio_amt_credits_less_100_credits_grt_500_3M      0
# 4                                        ecom_flag      0
# ..                                             ...    ...
# 207                     ratio_median_pos_amt_3M_6M      0
# 208                                   payroll_flag      0
# 209                           third_party_count_1M      0
# 210                           third_party_count_3M      0
# 211                           stddev_credit_amt_3M      0
#
# [212 rows x 2 columns]

# %%
def increase_counts(dataframe, feature_column, count_column, feat_list):
    dataframe.loc[dataframe[feature_column].isin(feat_list), count_column] += 1
    return dataframe
# increase_counts(feat_df,'feature_name','count',feat_list)
# feat_df.sort_values(by='count',ascending=False)

# %%
for seed in range(50):
    feat_list = main_func(df_raw, corr_arr,vif_arr,features_arr,iv_upper_limit,iv_lower_limit,seed)
    feat_df = increase_counts(feat_df,'feature_name','count',feat_list)
# Out:
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 191
# Information value of service_count_6M is 0.010823
# Information value of median_payroll_amt_3M is 0.02717
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.257612
# Information value of count_credits_100_to_500_6M is 0.094571
# Information value of sum_credits_100_to_500_6M is 0.080183
# Information value of count_credits_100_to_500_3M is 0.143433
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.10952
# Information value of shops_count_6M is 0.044836
# Information value of median_service_amt_1M is 0.000419
# Information value of ratio_pos_size_1M_3M is 0.000498
# Information value of ratio_shops_size_credit_size_6M is 0.140271
# Information value of median_pos_amt_3M is 0.07475
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.120326
# Information value of sum_credits_lessthan_100_3M is 0.215784
# Information value of median_loans_amt_6M is 0.0
# Information value of median_shops_amt_6M is 0.080985
# Information value of count_credits_grt_500_1M is 0.022963
# Information value of ach_size_6M is 0.000419
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.085642
# Information value of count_credits_100_to_500_1M is 0.093641
# Information value of service_amt_1M is 0.000189
# Information value of ratio_median_ecom_amt_3M_6M is 0.047183
# Information value of sum_credits_grt_500_3M is 0.075914
# Information value of third_party_amt_1M is 0.030015
# Information value of sum_credits_100_to_500_3M is 0.084894
# Information value of shops_amt_6M is 0.035659
# Information value of service_size_6M is 0.047306
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.034309
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.007031
# Information value of median_payroll_amt_1M is 0.037826
# Information value of ecom_size_3M is 0.061982
# Information value of ratio_credits_grt_1500_1M_3M is 0.042238
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.189838
# Information value of ratio_payroll_size_credit_size_6M is 0.090004
# Information value of pos_count_6M is 0.030755
# Information value of shops_size_1M is 0.007653
# Information value of total_credit_count_1M is 0.108231
# Information value of ratio_payroll_size_1M_6M is 0.000419
# Information value of ratio_service_size_credit_size_6M is 0.078766
# Information value of median_ecom_amt_6M is 0.189838
# Information value of third_party_count_6M is 0.104691
# Information value of median_credit_amt_6M is 0.226447
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.106051
# Information value of loans_size_6M is 0.0
# Information value of ratio_payroll_size_credit_size_1M is 0.007653
# Information value of pos_size_3M is 0.123008
# Information value of ach_amt_6M is 0.007653
# Information value of ach_size_3M is 0.002936
# Information value of shops_size_6M is 0.080985
# Information value of total_credit_count_6M is 0.179768
# Information value of median_third_party_amt_6M is 0.043421
# Information value of count_credits_grt_500_6M is 0.032074
# Information value of ratio_shops_size_credit_size_3M is 0.046147
# Information value of sum_credits_grt_1500_1M is 0.035196
# Information value of sum_credits_lessthan_100_1M is 0.120561
# Information value of sum_credits_lessthan_100_6M is 0.193552
# Information value of ratio_service_size_1M_6M is 0.000419
# Information value of ratio_shops_size_1M_6M is 0.002936
# Information value of ratio_credits_lessthan_100_1M_3M is 0.059453
# Information value of shops_count_1M is 0.008842
# Information value of ratio_median_shops_amt_3M_6M is 0.065104
# Information value of ratio_median_credit_amt_1M_3M is 0.159299
# Information value of ratio_median_credit_amt_1M_6M is 0.012586
# Information value of ach_count_6M is 0.006905
# Information value of median_third_party_amt_1M is 0.067914
# Information value of payroll_amt_6M is 0.015042
# Information value of ratio_credits_grt_500_1M_3M is 0.037608
# Information value of loans_amt_6M is 0.0
# Information value of ratio_pos_size_credit_size_1M is 0.031718
# Information value of count_credits_grt_1500_6M is 0.067799
# Information value of ratio_median_third_party_amt_3M_6M is 0.007937
# Information value of ratio_pos_size_credit_size_3M is 0.075309
# Information value of ratio_ach_size_credit_size_3M is 0.002936
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.024148
# Information value of credit_size_6M is 0.26657
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.169527
# Information value of sum_credits_100_to_500_1M is 0.100146
# Information value of total_credit_count_3M is 0.277314
# Information value of ratio_service_size_credit_size_3M is 0.014061
# Information value of ratio_service_size_credit_size_1M is 0.002936
# Information value of payroll_count_6M is 0.011502
# Information value of ach_count_3M is 0.005485
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.050149
# Information value of ratio_amt_credits_less_100_credits_grt_1500_3M is 0.153388
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.082196
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.104852
# Information value of ach_amt_3M is 0.002936
# Information value of median_shops_amt_1M is 0.002936
# Information value of median_payroll_amt_6M is 0.038446
# Information value of shops_amt_1M is 0.000189
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.054417
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.026805
# Information value of median_pos_amt_6M is 0.195353
# Information value of median_credit_amt_3M is 0.246275
# Information value of median_ach_amt_3M is 0.002936
# Information value of pos_amt_3M is 0.099316
# Information value of ratio_ecom_size_credit_size_6M is 0.21753
# Information value of ratio_credits_lessthan_100_1M_6M is 0.042992
# Information value of ratio_ecom_size_credit_size_3M is 0.061982
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.051204
# Information value of ratio_pos_size_1M_6M is 0.000498
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.107711
# Information value of median_ecom_amt_3M is 0.061982
# Information value of median_third_party_amt_3M is 0.034309
# Information value of loans_count_6M is 0.0
# Information value of ecom_count_6M is 0.122661
# Information value of service_count_1M is 0.001672
# Information value of median_ach_amt_6M is 0.002936
# Information value of sum_credits_grt_1500_3M is 0.066363
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.27822
# Information value of median_credit_amt_1M is 0.135775
# Information value of ratio_credits_grt_1500_1M_6M is 0.043539
# Information value of ecom_amt_6M is 0.163957
# Information value of count_credits_lessthan_100_3M is 0.144361
# Information value of sum_credits_grt_1500_6M is 0.054958
# Information value of payroll_count_1M is 0.006452
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.015042
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.023422
# Information value of pos_size_1M is 0.113204
# Information value of service_size_3M is 0.024148
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.125466
# Information value of payroll_amt_3M is 0.02717
# Information value of credit_size_1M is 0.096051
# Information value of total_credit_amt_1M is 0.027483
# Information value of pos_amt_1M is 0.147089
# Information value of ratio_service_size__1M_3M is 0.007653
# Information value of ratio_shops_size_credit_size_1M is 0.007653
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.034442
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.034309
# Information value of payroll_amt_1M is 0.02457
# Information value of ratio_shops_size_1M_3M is 0.014495
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.080842
# Information value of median_shops_amt_3M is 0.062091
# Information value of count_credits_lessthan_100_6M is 0.12089
# Information value of count_credits_grt_500_3M is 0.022092
# Information value of loans_count_1M is 0.072939
# Information value of third_party_amt_3M is 0.056099
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.05083
# Information value of total_credit_amt_6M is 0.082196
# Information value of third_party_amt_6M is 0.063732
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.000419
# Information value of shops_amt_3M is 0.054018
# Information value of count_credits_grt_1500_3M is 0.05315
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.126277
# Information value of shops_count_3M is 0.045188
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.00907
# Information value of ratio_ach_size_credit_size_6M is 0.000419
# Information value of service_amt_6M is 0.030475
# Information value of ratio_loans_size_credit_size_6M is 0.0
# Information value of ecom_amt_3M is 0.078675
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.015042
# Information value of payroll_size_3M is 0.02717
# Information value of shops_size_3M is 0.065104
# Information value of median_service_amt_6M is 0.049695
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.115067
# Information value of pos_size_6M is 0.368664
# Information value of ecom_count_3M is 0.048954
# Information value of pos_count_1M is 0.020188
# Information value of ratio_payroll_size_1M_3M is 0.007653
# Information value of median_pos_amt_1M is 0.113204
# Information value of ratio_median_ach_amt_3M_6M is 0.000419
# Information value of ratio_median_pos_amt_3M_6M is 0.051582
# Information value of third_party_count_1M is 0.059294
# Information value of third_party_count_3M is 0.090555
# Information value of stddev_credit_amt_3M is 0.156957
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 192
# Information value of service_count_6M is 0.054408
# Information value of median_payroll_amt_3M is 0.07475
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.332386
# Information value of count_credits_100_to_500_6M is 0.175386
# Information value of sum_credits_100_to_500_6M is 0.152232
# Information value of count_credits_100_to_500_3M is 0.168961
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.106137
# Information value of shops_count_6M is 0.066964
# Information value of median_service_amt_1M is 0.014495
# Information value of ratio_pos_size_1M_3M is 0.000419
# Information value of ratio_shops_size_credit_size_6M is 0.123009
# Information value of median_pos_amt_3M is 0.099068
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.140466
# Information value of sum_credits_lessthan_100_3M is 0.189162
# Information value of median_loans_amt_6M is 0.0
# Information value of median_shops_amt_6M is 0.098687
# Information value of count_credits_grt_500_1M is 0.034448
# Information value of ach_size_6M is 0.037826
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.131082
# Information value of count_credits_100_to_500_1M is 0.096013
# Information value of service_amt_1M is 0.007653
# Information value of ratio_median_ecom_amt_3M_6M is 0.007653
# Information value of sum_credits_grt_500_3M is 0.190397
# Information value of third_party_amt_1M is 0.022505
# Information value of sum_credits_100_to_500_3M is 0.139175
# Information value of shops_amt_6M is 0.020869
# Information value of service_size_6M is 0.025545
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.118504
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.024865
# Information value of median_payroll_amt_1M is 0.074679
# Information value of ecom_size_3M is 0.007653
# Information value of ratio_credits_grt_1500_1M_3M is 0.035105
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.061982
# Information value of ratio_payroll_size_credit_size_6M is 0.018383
# Information value of pos_count_6M is 0.024488
# Information value of shops_size_1M is 0.047183
# Information value of total_credit_count_1M is 0.086214
# Information value of ratio_payroll_size_1M_6M is 0.002352
# Information value of ratio_service_size_credit_size_6M is 0.109253
# Information value of ratio_amt_credits_less_100_credits_grt_500_6M is 0.199473
# Information value of median_ecom_amt_6M is 0.061982
# Information value of third_party_count_6M is 0.132713
# Information value of median_credit_amt_6M is 0.33154
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.136757
# Information value of loans_size_6M is 0.0
# Information value of ratio_payroll_size_credit_size_1M is 0.002352
# Information value of pos_size_3M is 0.037899
# Information value of ach_amt_6M is 0.014378
# Information value of ach_size_3M is 0.02457
# Information value of shops_size_6M is 0.035659
# Information value of total_credit_count_6M is 0.193151
# Information value of median_third_party_amt_6M is 0.071182
# Information value of count_credits_grt_500_6M is 0.050022
# Information value of ratio_shops_size_credit_size_3M is 0.080169
# Information value of sum_credits_grt_1500_1M is 0.082557
# Information value of sum_credits_lessthan_100_1M is 0.1197
# Information value of sum_credits_lessthan_100_6M is 0.189336
# Information value of ratio_service_size_1M_6M is 0.007653
# Information value of ratio_shops_size_1M_6M is 0.023398
# Information value of ratio_credits_lessthan_100_1M_3M is 0.02177
# Information value of shops_count_1M is 0.003551
# Information value of ratio_median_shops_amt_3M_6M is 0.124987
# Information value of ratio_median_credit_amt_1M_3M is 0.111773
# Information value of ratio_median_credit_amt_1M_6M is 0.030785
# Information value of ach_count_6M is 0.013109
# Information value of median_third_party_amt_1M is 0.046701
# Information value of payroll_amt_6M is 0.032164
# Information value of ratio_credits_grt_500_1M_3M is 0.012717
# Information value of loans_amt_6M is 0.0
# Information value of ratio_pos_size_credit_size_1M is 0.002352
# Information value of count_credits_grt_1500_6M is 0.179039
# Information value of ratio_median_third_party_amt_3M_6M is 0.011754
# Information value of ratio_pos_size_credit_size_3M is 0.023118
# Information value of ratio_ach_size_credit_size_3M is 0.014378
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.033428
# Information value of credit_size_6M is 0.437131
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.043557
# Information value of sum_credits_100_to_500_1M is 0.124774
# Information value of total_credit_count_3M is 0.20713
# Information value of ratio_service_size_credit_size_3M is 0.027424
# Information value of ratio_service_size_credit_size_1M is 0.047183
# Information value of ratio_credits_grt_500_1M_6M is 0.041897
# Information value of payroll_count_6M is 0.090562
# Information value of ach_count_3M is 0.017129
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.063447
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.233923
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.222788
# Information value of ach_amt_3M is 0.02457
# Information value of median_shops_amt_1M is 0.047183
# Information value of median_payroll_amt_6M is 0.054417
# Information value of shops_amt_1M is 0.034309
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.074679
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.054681
# Information value of median_pos_amt_6M is 0.149417
# Information value of median_credit_amt_3M is 0.250221
# Information value of median_ach_amt_3M is 0.02457
# Information value of pos_amt_3M is 0.043557
# Information value of ratio_ecom_size_credit_size_6M is 0.097237
# Information value of ratio_credits_lessthan_100_1M_6M is 0.013477
# Information value of ratio_ecom_size_credit_size_3M is 0.007653
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.059668
# Information value of ratio_pos_size_1M_6M is 0.000419
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.073657
# Information value of median_ecom_amt_3M is 0.007653
# Information value of median_third_party_amt_3M is 0.000498
# Information value of loans_count_6M is 0.0
# Information value of ecom_count_6M is 0.038991
# Information value of service_count_1M is 0.014554
# Information value of median_ach_amt_6M is 0.037826
# Information value of sum_credits_grt_1500_3M is 0.183224
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.370915
# Information value of median_credit_amt_1M is 0.141277
# Information value of ratio_credits_grt_1500_1M_6M is 0.049067
# Information value of ecom_amt_6M is 0.047183
# Information value of count_credits_lessthan_100_3M is 0.188219
# Information value of sum_credits_grt_1500_6M is 0.160345
# Information value of payroll_count_1M is 0.002652
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.076471
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.014131
# Information value of pos_size_1M is 0.02457
# Information value of service_size_3M is 0.020869
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.142209
# Information value of payroll_amt_3M is 0.055549
# Information value of credit_size_1M is 0.158885
# Information value of total_credit_amt_1M is 0.049111
# Information value of pos_amt_1M is 0.02457
# Information value of ratio_service_size__1M_3M is 0.034309
# Information value of ratio_shops_size_credit_size_1M is 0.078675
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.076466
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.02597
# Information value of payroll_amt_1M is 0.037826
# Information value of ratio_shops_size_1M_3M is 0.061982
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.095246
# Information value of median_shops_amt_3M is 0.08904
# Information value of count_credits_lessthan_100_6M is 0.145924
# Information value of count_credits_grt_500_3M is 0.071849
# Information value of loans_count_1M is 0.046655
# Information value of third_party_amt_3M is 0.06647
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.109735
# Information value of total_credit_amt_6M is 0.08213
# Information value of third_party_amt_6M is 0.070286
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.007653
# Information value of shops_amt_3M is 0.097956
# Information value of count_credits_grt_1500_3M is 0.086634
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.101512
# Information value of shops_count_3M is 0.028775
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.02902
# Information value of ratio_ach_size_credit_size_6M is 0.007031
# Information value of service_amt_6M is 0.009656
# Information value of ratio_loans_size_credit_size_6M is 0.0
# Information value of ecom_amt_3M is 0.007653
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.027265
# Information value of payroll_size_3M is 0.078077
# Information value of shops_size_3M is 0.083121
# Information value of median_service_amt_6M is 0.047977
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.184971
# Information value of pos_size_6M is 0.309951
# Information value of ecom_count_3M is 0.004412
# Information value of pos_count_1M is 0.00612
# Information value of ratio_payroll_size_1M_3M is 0.000419
# Information value of median_pos_amt_1M is 0.037826
# Information value of ratio_median_ach_amt_3M_6M is 0.054417
# Information value of ratio_median_pos_amt_3M_6M is 0.004202
# Information value of third_party_count_1M is 0.053113
# Information value of third_party_count_3M is 0.094332
# Information value of stddev_credit_amt_3M is 0.330957
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 192
# Information value of service_count_6M is 0.084396
# Information value of median_payroll_amt_3M is 0.081704
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.310322
# Information value of count_credits_100_to_500_6M is 0.186862
# Information value of sum_credits_100_to_500_6M is 0.156498
# Information value of count_credits_100_to_500_3M is 0.157545
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.094279
# Information value of shops_count_6M is 0.104761
# Information value of median_service_amt_1M is 0.002936
# Information value of ratio_pos_size_1M_3M is 0.031718
# Information value of ratio_shops_size_credit_size_6M is 0.203518
# Information value of median_pos_amt_3M is 0.06821
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.194226
# Information value of sum_credits_lessthan_100_3M is 0.144258
# Information value of median_loans_amt_6M is 0.0
# Information value of median_shops_amt_6M is 0.191467
# Information value of count_credits_grt_500_1M is 0.011165
# Information value of ach_size_6M is 0.002936
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.079643
# Information value of count_credits_100_to_500_1M is 0.147111
# Information value of service_amt_1M is 0.007653
# Information value of ratio_median_ecom_amt_3M_6M is 0.002936
# Information value of sum_credits_grt_500_3M is 0.107693
# Information value of third_party_amt_1M is 0.064968
# Information value of sum_credits_100_to_500_3M is 0.123847
# Information value of shops_amt_6M is 0.115335
# Information value of service_size_6M is 0.122403
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.078541
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.008395
# Information value of median_payroll_amt_1M is 0.02457
# Information value of ecom_size_3M is 0.007653
# Information value of ratio_credits_grt_1500_1M_3M is 0.074778
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.034309
# Information value of ratio_payroll_size_credit_size_6M is 0.031718
# Information value of pos_count_6M is 0.015354
# Information value of shops_size_1M is 0.014495
# Information value of total_credit_count_1M is 0.086064
# Information value of ratio_payroll_size_1M_6M is 0.000419
# Information value of ratio_service_size_credit_size_6M is 0.168607
# Information value of ratio_amt_credits_less_100_credits_grt_500_6M is 0.195248
# Information value of median_ecom_amt_6M is 0.034309
# Information value of third_party_count_6M is 0.184201
# Information value of median_credit_amt_6M is 0.263379
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.083747
# Information value of loans_size_6M is 0.0
# Information value of ratio_payroll_size_credit_size_1M is 0.007653
# Information value of pos_size_3M is 0.04967
# Information value of ach_amt_6M is 0.034309
# Information value of ach_size_3M is 0.023398
# Information value of shops_size_6M is 0.191467
# Information value of total_credit_count_6M is 0.124034
# Information value of median_third_party_amt_6M is 0.108407
# Information value of count_credits_grt_500_6M is 0.012277
# Information value of ratio_shops_size_credit_size_3M is 0.119496
# Information value of sum_credits_grt_1500_1M is 0.11403
# Information value of sum_credits_lessthan_100_1M is 0.123116
# Information value of sum_credits_lessthan_100_6M is 0.214893
# Information value of ratio_service_size_1M_6M is 0.014495
# Information value of ratio_shops_size_1M_6M is 0.007653
# Information value of ratio_credits_lessthan_100_1M_3M is 0.004633
# Information value of shops_count_1M is 5.2e-05
# Information value of ratio_median_shops_amt_3M_6M is 0.143154
# Information value of ratio_median_credit_amt_1M_3M is 0.113355
# Information value of ratio_median_credit_amt_1M_6M is 0.030728
# Information value of ach_count_6M is 0.00507
# Information value of median_third_party_amt_1M is 0.08904
# Information value of payroll_amt_6M is 0.008225
# Information value of ratio_credits_grt_500_1M_3M is 0.010738
# Information value of loans_amt_6M is 0.0
# Information value of ratio_pos_size_credit_size_1M is 0.007031
# Information value of count_credits_grt_1500_6M is 0.131123
# Information value of ratio_median_third_party_amt_3M_6M is 0.163236
# Information value of ratio_pos_size_credit_size_3M is 0.039977
# Information value of ratio_ach_size_credit_size_3M is 0.034309
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.119947
# Information value of credit_size_6M is 0.310282
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.175327
# Information value of sum_credits_100_to_500_1M is 0.164953
# Information value of total_credit_count_3M is 0.160593
# Information value of ratio_service_size_credit_size_3M is 0.078541
# Information value of ratio_service_size_credit_size_1M is 0.023398
# Information value of payroll_count_6M is 0.042508
# Information value of ach_count_3M is 0.01821
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.04859
# Information value of ratio_amt_credits_less_100_credits_grt_1500_3M is 0.089611
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.155513
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.247674
# Information value of ach_amt_3M is 0.034309
# Information value of median_shops_amt_1M is 0.023398
# Information value of median_payroll_amt_6M is 0.057901
# Information value of shops_amt_1M is 0.007653
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.054417
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.006433
# Information value of median_pos_amt_6M is 0.214335
# Information value of median_credit_amt_3M is 0.191494
# Information value of median_ach_amt_3M is 0.023398
# Information value of pos_amt_3M is 0.04967
# Information value of ratio_ecom_size_credit_size_6M is 0.061982
# Information value of ratio_credits_lessthan_100_1M_6M is 0.018797
# Information value of ratio_ecom_size_credit_size_3M is 0.002936
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.032338
# Information value of ratio_pos_size_1M_6M is 0.008225
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.031935
# Information value of median_ecom_amt_3M is 0.002936
# Information value of median_third_party_amt_3M is 0.141207
# Information value of loans_count_6M is 0.0
# Information value of ecom_count_6M is 0.037085
# Information value of service_count_1M is 0.001261
# Information value of median_ach_amt_6M is 0.000419
# Information value of sum_credits_grt_1500_3M is 0.151342
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.30934
# Information value of median_credit_amt_1M is 0.148299
# Information value of ratio_credits_grt_1500_1M_6M is 0.105793
# Information value of ecom_amt_6M is 0.034309
# Information value of count_credits_lessthan_100_3M is 0.138977
# Information value of sum_credits_grt_1500_6M is 0.130438
# Information value of payroll_count_1M is 0.01024
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.072024
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.001001
# Information value of pos_size_1M is 0.045806
# Information value of service_size_3M is 0.10295
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.044022
# Information value of payroll_amt_3M is 0.023118
# Information value of credit_size_1M is 0.197967
# Information value of total_credit_amt_1M is 0.03784
# Information value of pos_amt_1M is 0.031718
# Information value of ratio_service_size__1M_3M is 0.023398
# Information value of ratio_shops_size_credit_size_1M is 0.034309
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.071362
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.089175
# Information value of payroll_amt_1M is 0.007031
# Information value of ratio_shops_size_1M_3M is 0.023398
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.117764
# Information value of median_shops_amt_3M is 0.119496
# Information value of count_credits_lessthan_100_6M is 0.07778
# Information value of count_credits_grt_500_3M is 0.019461
# Information value of loans_count_1M is 0.051633
# Information value of third_party_amt_3M is 0.102775
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.066932
# Information value of total_credit_amt_6M is 0.067724
# Information value of third_party_amt_6M is 0.098071
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.002936
# Information value of shops_amt_3M is 0.132753
# Information value of count_credits_grt_1500_3M is 0.103176
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.084739
# Information value of shops_count_3M is 0.045637
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.038753
# Information value of ratio_ach_size_credit_size_6M is 0.014495
# Information value of service_amt_6M is 0.078766
# Information value of ratio_loans_size_credit_size_6M is 0.0
# Information value of ecom_amt_3M is 0.007653
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.031718
# Information value of payroll_size_3M is 0.057901
# Information value of shops_size_3M is 0.149093
# Information value of median_service_amt_6M is 0.129645
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.157913
# Information value of pos_size_6M is 0.280749
# Information value of ecom_count_3M is 0.019264
# Information value of pos_count_1M is 0.003117
# Information value of ratio_payroll_size_1M_3M is 0.007653
# Information value of median_pos_amt_1M is 0.072024
# Information value of ratio_median_ach_amt_3M_6M is 0.000189
# Information value of ratio_median_pos_amt_3M_6M is 0.030015
# Information value of third_party_count_1M is 0.08238
# Information value of third_party_count_3M is 0.149002
# Information value of stddev_credit_amt_3M is 0.277521
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 192
# Information value of service_count_6M is 0.076196
# Information value of median_payroll_amt_3M is 0.04967
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.365282
# Information value of count_credits_100_to_500_6M is 0.15966
# Information value of sum_credits_100_to_500_6M is 0.147553
# Information value of count_credits_100_to_500_3M is 0.153668
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.132991
# Information value of shops_count_6M is 0.065163
# Information value of median_service_amt_1M is 0.000189
# Information value of ratio_pos_size_1M_3M is 0.015042
# Information value of ratio_shops_size_credit_size_6M is 0.189838
# Information value of median_pos_amt_3M is 0.05674
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.152322
# Information value of sum_credits_lessthan_100_3M is 0.23988
# Information value of median_loans_amt_6M is 0.014495
# Information value of median_shops_amt_6M is 0.126809
# Information value of count_credits_grt_500_1M is 0.026437
# Information value of ach_size_6M is 0.000189
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.126566
# Information value of count_credits_100_to_500_1M is 0.116547
# Information value of service_amt_1M is 0.000189
# Information value of ratio_median_ecom_amt_3M_6M is 0.014495
# Information value of sum_credits_grt_500_3M is 0.131082
# Information value of third_party_amt_1M is 0.020869
# Information value of sum_credits_100_to_500_3M is 0.11528
# Information value of shops_amt_6M is 0.04777
# Information value of service_size_6M is 0.138264
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.047977
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.004202
# Information value of median_payroll_amt_1M is 0.037826
# Information value of ecom_size_3M is 0.014495
# Information value of ratio_credits_grt_1500_1M_3M is 0.085494
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.078675
# Information value of ratio_payroll_size_credit_size_6M is 0.057901
# Information value of pos_count_6M is 0.030075
# Information value of shops_size_1M is 0.000419
# Information value of total_credit_count_1M is 0.0961
# Information value of ratio_payroll_size_1M_6M is 0.000419
# Information value of ratio_service_size_credit_size_6M is 0.098737
# Information value of ratio_amt_credits_less_100_credits_grt_500_6M is 0.294367
# Information value of median_ecom_amt_6M is 0.117647
# Information value of third_party_count_6M is 0.145949
# Information value of median_credit_amt_6M is 0.384723
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.136182
# Information value of loans_size_6M is 0.014495
# Information value of ratio_payroll_size_credit_size_1M is 0.014495
# Information value of pos_size_3M is 0.046919
# Information value of ach_amt_6M is 0.000419
# Information value of ach_size_3M is 0.002936
# Information value of shops_size_6M is 0.129645
# Information value of total_credit_count_6M is 0.179973
# Information value of median_third_party_amt_6M is 0.089029
# Information value of count_credits_grt_500_6M is 0.028767
# Information value of ratio_shops_size_credit_size_3M is 0.070538
# Information value of sum_credits_grt_1500_1M is 0.079588
# Information value of sum_credits_lessthan_100_1M is 0.117929
# Information value of sum_credits_lessthan_100_6M is 0.224197
# Information value of ratio_service_size_1M_6M is 0.000419
# Information value of ratio_shops_size_1M_6M is 0.002936
# Information value of ratio_credits_lessthan_100_1M_3M is 0.02229
# Information value of shops_count_1M is 0.000144
# Information value of ratio_median_shops_amt_3M_6M is 0.079479
# Information value of ratio_median_credit_amt_1M_3M is 0.183054
# Information value of ratio_median_credit_amt_1M_6M is 0.031466
# Information value of ach_count_6M is 0.001153
# Information value of median_third_party_amt_1M is 0.033215
# Information value of payroll_amt_6M is 0.031718
# Information value of ratio_credits_grt_500_1M_3M is 0.019167
# Information value of loans_amt_6M is 0.014495
# Information value of ratio_pos_size_credit_size_1M is 0.003048
# Information value of count_credits_grt_1500_6M is 0.122713
# Information value of ratio_median_third_party_amt_3M_6M is 0.152511
# Information value of ratio_pos_size_credit_size_3M is 0.027265
# Information value of ratio_ach_size_credit_size_3M is 0.002936
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.118504
# Information value of credit_size_6M is 0.347564
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.099688
# Information value of sum_credits_100_to_500_1M is 0.124162
# Information value of total_credit_count_3M is 0.168579
# Information value of ratio_service_size_credit_size_3M is 0.079479
# Information value of ratio_service_size_credit_size_1M is 0.000189
# Information value of payroll_count_6M is 0.011519
# Information value of ach_count_3M is 0.003191
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.062451
# Information value of ratio_amt_credits_less_100_credits_grt_1500_3M is 0.13744
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.22733
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.104831
# Information value of ach_amt_3M is 0.007653
# Information value of median_shops_amt_1M is 0.002936
# Information value of median_payroll_amt_6M is 0.047306
# Information value of shops_amt_1M is 0.000419
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.037826
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.00546
# Information value of median_pos_amt_6M is 0.17401
# Information value of median_credit_amt_3M is 0.315414
# Information value of median_ach_amt_3M is 0.002936
# Information value of pos_amt_3M is 0.054417
# Information value of ratio_ecom_size_credit_size_6M is 0.117647
# Information value of ratio_credits_lessthan_100_1M_6M is 0.013477
# Information value of ratio_ecom_size_credit_size_3M is 0.034309
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.061304
# Information value of ratio_pos_size_1M_6M is 0.02717
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.112633
# Information value of median_ecom_amt_3M is 0.023398
# Information value of median_third_party_amt_3M is 0.104967
# Information value of loans_count_6M is 0.024389
# Information value of ecom_count_6M is 0.035099
# Information value of service_count_1M is 0.005485
# Information value of median_ach_amt_6M is 0.002936
# Information value of sum_credits_grt_1500_3M is 0.159036
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.318058
# Information value of median_credit_amt_1M is 0.216242
# Information value of ratio_credits_grt_1500_1M_6M is 0.064267
# Information value of ecom_amt_6M is 0.097237
# Information value of count_credits_lessthan_100_3M is 0.236422
# Information value of sum_credits_grt_1500_6M is 0.122309
# Information value of payroll_count_1M is 0.001504
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.110151
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.02013
# Information value of pos_size_1M is 0.02717
# Information value of service_size_3M is 0.097237
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.166928
# Information value of payroll_amt_3M is 0.081704
# Information value of credit_size_1M is 0.191618
# Information value of total_credit_amt_1M is 0.051604
# Information value of pos_amt_1M is 0.003048
# Information value of ratio_service_size__1M_3M is 0.007653
# Information value of ratio_shops_size_credit_size_1M is 0.002936
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.079643
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.111298
# Information value of payroll_amt_1M is 0.037826
# Information value of ratio_shops_size_1M_3M is 0.014495
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.102685
# Information value of median_shops_amt_3M is 0.118504
# Information value of count_credits_lessthan_100_6M is 0.13517
# Information value of count_credits_grt_500_3M is 0.093033
# Information value of loans_count_1M is 0.042323
# Information value of third_party_amt_3M is 0.083297
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.086387
# Information value of total_credit_amt_6M is 0.061691
# Information value of third_party_amt_6M is 0.050978
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.002352
# Information value of shops_amt_3M is 0.065104
# Information value of count_credits_grt_1500_3M is 0.085975
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.090436
# Information value of shops_count_3M is 0.018608
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.023169
# Information value of ratio_ach_size_credit_size_6M is 0.002352
# Information value of service_amt_6M is 0.038446
# Information value of ratio_loans_size_credit_size_6M is 0.014495
# Information value of ecom_amt_3M is 0.034309
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.004238
# Information value of payroll_size_3M is 0.04967
# Information value of shops_size_3M is 0.098687
# Information value of median_service_amt_6M is 0.110151
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.239713
# Information value of pos_size_6M is 0.358265
# Information value of ecom_count_3M is 0.00189
# Information value of pos_count_1M is 0.003128
# Information value of ratio_payroll_size_1M_3M is 0.007653
# Information value of median_pos_amt_1M is 0.015042
# Information value of ratio_median_ach_amt_3M_6M is 0.014378
# Information value of ratio_median_pos_amt_3M_6M is 0.001122
# Information value of third_party_count_1M is 0.039598
# Information value of third_party_count_3M is 0.123305
# Information value of stddev_credit_amt_3M is 0.266347
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 192
# Information value of service_count_6M is 0.073933
# Information value of median_payroll_amt_3M is 0.075309
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.345648
# Information value of count_credits_100_to_500_6M is 0.142284
# Information value of sum_credits_100_to_500_6M is 0.144549
# Information value of count_credits_100_to_500_3M is 0.138867
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.130131
# Information value of shops_count_6M is 0.08862
# Information value of median_service_amt_1M is 0.000189
# Information value of ratio_pos_size_1M_3M is 0.002936
# Information value of ratio_shops_size_credit_size_6M is 0.078541
# Information value of median_pos_amt_3M is 0.014452
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.259622
# Information value of sum_credits_lessthan_100_3M is 0.14085
# Information value of median_loans_amt_6M is 0.023398
# Information value of median_shops_amt_6M is 0.111298
# Information value of count_credits_grt_500_1M is 0.047229
# Information value of ach_size_6M is 0.005904
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.099781
# Information value of count_credits_100_to_500_1M is 0.104856
# Information value of service_amt_1M is 0.000419
# Information value of ratio_median_ecom_amt_3M_6M is 0.034309
# Information value of sum_credits_grt_500_3M is 0.110867
# Information value of third_party_amt_1M is 0.022304
# Information value of sum_credits_100_to_500_3M is 0.1197
# Information value of shops_amt_6M is 0.024148
# Information value of service_size_6M is 0.057901
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.035659
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.006199
# Information value of median_payroll_amt_1M is 0.037826
# Information value of ecom_size_3M is 0.034309
# Information value of ratio_credits_grt_1500_1M_3M is 0.062527
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.097237
# Information value of ratio_payroll_size_credit_size_6M is 0.01627
# Information value of pos_count_6M is 0.034045
# Information value of shops_size_1M is 0.007653
# Information value of total_credit_count_1M is 0.095089
# Information value of ratio_payroll_size_1M_6M is 0.000189
# Information value of ratio_service_size_credit_size_6M is 0.065104
# Information value of ratio_amt_credits_less_100_credits_grt_500_6M is 0.291318
# Information value of median_ecom_amt_6M is 0.025684
# Information value of third_party_count_6M is 0.110994
# Information value of median_credit_amt_6M is 0.287496
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.077172
# Information value of loans_size_6M is 0.023398
# Information value of ratio_payroll_size_credit_size_1M is 0.000419
# Information value of pos_size_3M is 0.038485
# Information value of ach_amt_6M is 0.002352
# Information value of ach_size_3M is 0.002936
# Information value of shops_size_6M is 0.051582
# Information value of total_credit_count_6M is 0.209855
# Information value of median_third_party_amt_6M is 0.090247
# Information value of count_credits_grt_500_6M is 0.007535
# Information value of ratio_shops_size_credit_size_3M is 0.046147
# Information value of sum_credits_grt_1500_1M is 0.08626
# Information value of sum_credits_lessthan_100_1M is 0.124987
# Information value of sum_credits_lessthan_100_6M is 0.159904
# Information value of ratio_service_size_1M_6M is 0.007653
# Information value of ratio_shops_size_1M_6M is 0.007653
# Information value of ratio_credits_lessthan_100_1M_3M is 0.049226
# Information value of shops_count_1M is 0.007106
# Information value of ratio_median_shops_amt_3M_6M is 0.119947
# Information value of ratio_median_credit_amt_1M_3M is 0.057468
# Information value of ratio_median_credit_amt_1M_6M is 0.081223
# Information value of ach_count_6M is 0.000403
# Information value of median_third_party_amt_1M is 0.039637
# Information value of payroll_amt_6M is 0.054417
# Information value of ratio_credits_grt_500_1M_3M is 0.007496
# Information value of loans_amt_6M is 0.023398
# Information value of ratio_pos_size_credit_size_1M is 0.007031
# Information value of count_credits_grt_1500_6M is 0.102833
# Information value of ratio_median_third_party_amt_3M_6M is 0.083121
# Information value of ratio_pos_size_credit_size_3M is 0.020596
# Information value of ratio_ach_size_credit_size_3M is 0.000419
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.078766
# Information value of credit_size_6M is 0.30934
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.05949
# Information value of sum_credits_100_to_500_1M is 0.124774
# Information value of total_credit_count_3M is 0.192298
# Information value of ratio_service_size_credit_size_3M is 0.039637
# Information value of ratio_service_size_credit_size_1M is 0.002936
# Information value of payroll_count_6M is 0.032695
# Information value of ach_count_3M is 0.000391
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.056349
# ...
# Information value of count_credits_grt_1500_1M is 0.098293
# Information value of ratio_amt_credits_less_100_credits_grt_1500_3M is 0.153388
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.114515
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.116686
# Information value of ach_amt_3M is 0.014495
# Information value of median_shops_amt_1M is 0.023398
# Information value of median_payroll_amt_6M is 0.015042
# Information value of shops_amt_1M is 0.007653
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.02457
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.010235
# Information value of median_pos_amt_6M is 0.213084
# Information value of median_credit_amt_3M is 0.264134
# Information value of median_ach_amt_3M is 0.007653
# Information value of pos_amt_3M is 0.099316
# Information value of ratio_ecom_size_credit_size_6M is 0.078675
# Information value of ratio_credits_lessthan_100_1M_6M is 0.002657
# Information value of ratio_ecom_size_credit_size_3M is 0.034309
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.023634
# Information value of ratio_pos_size_1M_6M is 0.032164
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.094558
# Information value of median_ecom_amt_3M is 0.014495
# Information value of median_third_party_amt_3M is 0.00494
# Information value of loans_count_6M is 0.052995
# Information value of ecom_count_6M is 0.085799
# Information value of service_count_1M is 0.000266
# Information value of median_ach_amt_6M is 0.000419
# Information value of sum_credits_grt_1500_3M is 0.148627
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.35582
# Information value of median_credit_amt_1M is 0.195089
# Information value of ratio_credits_grt_1500_1M_6M is 0.048607
# Information value of ecom_amt_6M is 0.078675
# Information value of count_credits_lessthan_100_3M is 0.091297
# Information value of sum_credits_grt_1500_6M is 0.138143
# Information value of payroll_count_1M is 0.00502
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.037899
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.015705
# Information value of pos_size_1M is 0.055576
# Information value of service_size_3M is 0.065104
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.062526
# Information value of payroll_amt_3M is 0.039613
# Information value of credit_size_1M is 0.183695
# Information value of total_credit_amt_1M is 0.097276
# Information value of pos_amt_1M is 0.07475
# Information value of ratio_service_size__1M_3M is 0.007653
# Information value of ratio_shops_size_credit_size_1M is 0.014495
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.145476
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.051787
# Information value of payroll_amt_1M is 0.02457
# Information value of ratio_shops_size_1M_3M is 0.014495
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.09945
# Information value of median_shops_amt_3M is 0.074273
# Information value of count_credits_lessthan_100_6M is 0.08913
# Information value of count_credits_grt_500_3M is 0.063476
# Information value of loans_count_1M is 0.064462
# Information value of third_party_amt_3M is 0.04727
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.142205
# Information value of total_credit_amt_6M is 0.082181
# Information value of third_party_amt_6M is 0.052234
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.007653
# Information value of shops_amt_3M is 0.089175
# Information value of count_credits_grt_1500_3M is 0.141591
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.157678
# Information value of shops_count_3M is 0.012948
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.008686
# Information value of ratio_ach_size_credit_size_6M is 0.002936
# Information value of service_amt_6M is 0.039977
# Information value of ratio_loans_size_credit_size_6M is 0.034309
# Information value of ecom_amt_3M is 0.034309
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.01627
# Information value of payroll_size_3M is 0.024862
# Information value of shops_size_3M is 0.089175
# Information value of median_service_amt_6M is 0.051582
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.155009
# Information value of pos_size_6M is 0.424437
# Information value of ecom_count_3M is 0.057436
# Information value of pos_count_1M is 0.027675
# Information value of ratio_payroll_size_1M_3M is 0.000419
# Information value of median_pos_amt_1M is 0.099316
# Information value of ratio_median_ach_amt_3M_6M is 0.000419
# Information value of ratio_median_pos_amt_3M_6M is 0.002936
# Information value of third_party_count_1M is 0.014659
# Information value of third_party_count_3M is 0.03595
# Information value of stddev_credit_amt_3M is 0.203262
# x_train.shape = (445, 211) | y_train.shape = (445,) | x_test.shape = (192, 211) | y_test.shape = (192,)
# col_list_exc_bool = 192
# Information value of service_count_6M is 0.055805
# Information value of median_payroll_amt_3M is 0.094932
# Information value of ratio_amt_credits_less_100_credits_grt_500_3M is 0.371103
# Information value of count_credits_100_to_500_6M is 0.152752
# Information value of sum_credits_100_to_500_6M is 0.158744
# Information value of count_credits_100_to_500_3M is 0.18251
# Information value of ratio_cnt_credits_less_100_credits_grt_500_3M is 0.163608
# Information value of shops_count_6M is 0.081449
# Information value of median_service_amt_1M is 0.002352
# Information value of ratio_pos_size_1M_3M is 0.014378
# Information value of ratio_shops_size_credit_size_6M is 0.119947
# Information value of median_pos_amt_3M is 0.101512
# Information value of ratio_amt_credits_less_100_credits_grt_1500_6M is 0.188577
# Information value of sum_credits_lessthan_100_3M is 0.252686
# Information value of median_loans_amt_6M is 0.0
# Information value of median_shops_amt_6M is 0.025545
# Information value of count_credits_grt_500_1M is 0.012505
# Information value of ach_size_6M is 0.000189
# Information value of median_loans_amt_3M is 0.0
# Information value of sum_credits_grt_500_6M is 0.085642
# Information value of count_credits_100_to_500_1M is 0.133235
# Information value of service_amt_1M is 0.000189
# Information value of ratio_median_ecom_amt_3M_6M is 0.023398
# Information value of sum_credits_grt_500_3M is 0.118923
# Information value of third_party_amt_1M is 0.033215
# Information value of sum_credits_100_to_500_3M is 0.203518
# Information value of shops_amt_6M is 0.035659
# Information value of service_size_6M is 0.094932
# Information value of ratio_ecom_size_1M_3M is 0.0
# Information value of ratio_median_service_amt_3M_6M is 0.039637
# Information value of ratio_loans_size_credit_size_1M is 0.0
# Information value of ratio_payroll_size_credit_size_3M is 0.017415
# Information value of median_payroll_amt_1M is 0.014378
# Information value of ecom_size_3M is 0.034309
# Information value of ratio_credits_grt_1500_1M_3M is 0.063999
# Information value of ach_count_1M is 0.0
# Information value of ecom_size_6M is 0.078675
# Information value of ratio_payroll_size_credit_size_6M is 0.090004
# Information value of pos_count_6M is 0.069811
# Information value of shops_size_1M is 0.002936
# Information value of total_credit_count_1M is 0.079199
# Information value of ratio_payroll_size_1M_6M is 0.000419
# Information value of ratio_service_size_credit_size_6M is 0.118504
# Information value of ratio_amt_credits_less_100_credits_grt_500_6M is 0.279569
# Information value of median_ecom_amt_6M is 0.061982
# Information value of third_party_count_6M is 0.091577
# Information value of median_credit_amt_6M is 0.265022
# Information value of ratio_loan_size_1M_6M is 0.0
# Information value of count_credits_lessthan_100_1M is 0.067338
# Information value of loans_size_6M is 0.0
# Information value of ratio_payroll_size_credit_size_1M is 0.023398
# Information value of pos_size_3M is 0.074679
# Information value of ach_amt_6M is 0.014495
# Information value of ach_size_3M is 0.007653
# Information value of shops_size_6M is 0.080985
# Information value of total_credit_count_6M is 0.146204
# Information value of median_third_party_amt_6M is 0.096371
# Information value of count_credits_grt_500_6M is 0.004825
# Information value of ratio_shops_size_credit_size_3M is 0.08904
# Information value of sum_credits_grt_1500_1M is 0.126166
# Information value of sum_credits_lessthan_100_1M is 0.093232
# Information value of sum_credits_lessthan_100_6M is 0.273997
# Information value of ratio_service_size_1M_6M is 0.007653
# Information value of ratio_shops_size_1M_6M is 0.014495
# Information value of ratio_credits_lessthan_100_1M_3M is 0.123373
# Information value of shops_count_1M is 0.011038
# Information value of ratio_median_shops_amt_3M_6M is 0.054018
# Information value of ratio_median_credit_amt_1M_3M is 0.056231
# Information value of ratio_median_credit_amt_1M_6M is 0.024148
# Information value of ach_count_6M is 0.025684
# Information value of median_third_party_amt_1M is 0.034309
# Information value of payroll_amt_6M is 0.06821
# Information value of ratio_credits_grt_500_1M_3M is 0.04887
# Information value of loans_amt_6M is 0.0
# Information value of ratio_pos_size_credit_size_1M is 0.014378
# Information value of count_credits_grt_1500_6M is 0.137934
# Information value of ratio_median_third_party_amt_3M_6M is 0.084835
# Information value of ratio_pos_size_credit_size_3M is 0.038485
# Information value of ratio_ach_size_credit_size_3M is 0.014495
# Information value of ratio_loans_size_credit_size_3M is 0.0
# Information value of service_amt_3M is 0.117741
# Information value of credit_size_6M is 0.283142
# Information value of ratio_ach_size_1M_3M is 0.0
# Information value of ratio_ecom_size_1M_6M is 0.0
# Information value of ratio_pos_size_credit_size_6M is 0.165731
# Information value of sum_credits_100_to_500_1M is 0.160279
# Information value of total_credit_count_3M is 0.184008
# Information value of ratio_service_size_credit_size_3M is 0.10295
# Information value of ratio_service_size_credit_size_1M is 0.007653
# Information value of payroll_count_6M is 0.005118
# Information value of ach_count_3M is 0.007413
# Information value of median_ecom_amt_1M is 0.0
# Information value of ratio_ach_size_1M_6M is 0.0
# Information value of count_credits_grt_1500_1M is 0.066775
# Information value of ratio_amt_credits_less_100_credits_grt_1500_3M is 0.163942
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_6M is 0.139082
# Information value of ratio_ecom_size_credit_size_1M is 0.0
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_6M is 0.187709
# Information value of ach_amt_3M is 0.007653
# Information value of median_shops_amt_1M is 4.4e-05
# Information value of median_payroll_amt_6M is 0.06821
# Information value of shops_amt_1M is 0.000419
# Information value of loans_amt_1M is 0.0
# Information value of payroll_size_1M is 0.037826
# Information value of median_ach_amt_1M is 0.0
# Information value of payroll_count_3M is 0.003791
# Information value of median_pos_amt_6M is 0.14962
# Information value of median_credit_amt_3M is 0.215153
# Information value of median_ach_amt_3M is 0.002936
# Information value of pos_amt_3M is 0.038485
# Information value of ratio_ecom_size_credit_size_6M is 0.078675
# Information value of ratio_credits_lessthan_100_1M_6M is 0.036362
# Information value of ratio_ecom_size_credit_size_3M is 0.047183
# Information value of ratio_amt_credits_grt_500_credits_grt_1500_3M is 0.032338
# Information value of ratio_pos_size_1M_6M is 0.002352
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_3M is 0.036129
# Information value of median_ecom_amt_3M is 0.023398
# Information value of median_third_party_amt_3M is 0.082055
# Information value of loans_count_6M is 0.0
# Information value of ecom_count_6M is 0.095664
# Information value of service_count_1M is 0.015673
# Information value of median_ach_amt_6M is 0.000419
# Information value of sum_credits_grt_1500_3M is 0.141451
# Information value of ach_size_1M is 0.0
# Information value of credit_size_3M is 0.279715
# Information value of median_credit_amt_1M is 0.209712
# Information value of ratio_credits_grt_1500_1M_6M is 0.036391
# Information value of ecom_amt_6M is 0.078675
# Information value of count_credits_lessthan_100_3M is 0.181325
# Information value of sum_credits_grt_1500_6M is 0.093584
# Information value of payroll_count_1M is 0.000566
# Information value of ecom_amt_1M is 0.0
# Information value of payroll_size_6M is 0.143633
# Information value of loans_count_3M is 0.0
# Information value of ecom_count_1M is 0.0
# Information value of pos_count_3M is 0.031829
# Information value of pos_size_1M is 0.054417
# Information value of service_size_3M is 0.098687
# Information value of ratio_cnt_credits_grt_500_credits_grt_1500_3M is 0.109303
# Information value of payroll_amt_3M is 0.080563
# Information value of credit_size_1M is 0.172119
# Information value of total_credit_amt_1M is 0.081146
# Information value of pos_amt_1M is 0.02457
# Information value of ratio_service_size__1M_3M is 0.002936
# Information value of ratio_shops_size_credit_size_1M is 0.014495
# Information value of loans_size_1M is 0.0
# Information value of sum_credits_grt_500_1M is 0.087207
# Information value of ratio_loan_size_1M_3M is 0.0
# Information value of median_service_amt_3M is 0.098687
# Information value of payroll_amt_1M is 0.02457
# Information value of ratio_shops_size_1M_3M is 0.014495
# Information value of ratio_cnt_credits_less_100_credits_grt_1500_6M is 0.109977
# Information value of median_shops_amt_3M is 0.082986
# Information value of count_credits_lessthan_100_6M is 0.127418
# Information value of count_credits_grt_500_3M is 0.113549
# Information value of loans_count_1M is 0.060964
# Information value of third_party_amt_3M is 0.046363
# Information value of ratio_ach_size_credit_size_1M is 0.0
# Information value of total_credit_amt_3M is 0.066356
# Information value of total_credit_amt_6M is 0.027483
# Information value of third_party_amt_6M is 0.041194
# Information value of ach_amt_1M is 0.0
# Information value of service_size_1M is 0.002352
# Information value of shops_amt_3M is 0.098687
# Information value of count_credits_grt_1500_3M is 0.041266
# Information value of median_loans_amt_1M is 0.0
# Information value of pos_amt_6M is 0.087207
# Information value of shops_count_3M is 0.056247
# Information value of loans_size_3M is 0.0
# Information value of service_count_3M is 0.043279
# Information value of ratio_ach_size_credit_size_6M is 0.002936
# Information value of service_amt_6M is 0.025739
# Information value of ratio_loans_size_credit_size_6M is 0.0
# Information value of ecom_amt_3M is 0.047183
# Information value of ratio_median_loan_amt_3M_6M is 0.0
# Information value of loans_amt_3M is 0.0
# Information value of ecom_size_1M is 0.0
# Information value of ratio_median_payroll_amt_3M_6M is 0.002936
# Information value of payroll_size_3M is 0.071264
# Information value of shops_size_3M is 0.10295
# Information value of median_service_amt_6M is 0.047306
# Information value of ratio_cnt_credits_less_100_credits_grt_500_6M is 0.212368
# Information value of pos_size_6M is 0.314157
# Information value of ecom_count_3M is 0.053312
# Information value of pos_count_1M is 0.00167
# Information value of ratio_payroll_size_1M_3M is 0.014495
# Information value of median_pos_amt_1M is 0.074679
# Information value of ratio_median_ach_amt_3M_6M is 0.014378
# Information value of ratio_median_pos_amt_3M_6M is 0.007735
# Information value of third_party_count_1M is 0.068445
# Information value of third_party_count_3M is 0.079498
# Information value of stddev_credit_amt_3M is 0.233635

# %%
feat_df
# Out:
#                                       feature_name  count
# 0                                 service_count_6M      0
# 1                            median_payroll_amt_3M      0
# 2                     ratio_third_party_size_1M_6M      0
# 3    ratio_amt_credits_less_100_credits_grt_500_3M      0
# 4                                        ecom_flag      0
# ..                                             ...    ...
# 207                     ratio_median_pos_amt_3M_6M      3
# 208                                   payroll_flag      0
# 209                           third_party_count_1M      2
# 210                           third_party_count_3M      4
# 211                           stddev_credit_amt_3M     16
#
# [212 rows x 2 columns]

# %%
feature_list = list(feat_df.sort_values(by='count',ascending=False)['feature_name'])

# %%
corr_df, subset_df = sel.get_correlated_features(df_raw, feature_list, thresh=corr_arr)
corr_df[np.abs(corr_df['corr'])<0.6]
# Out:
#                           feature_1                      feature_2      corr
# 1     ratio_pos_size_credit_size_6M  ratio_pos_size_credit_size_1M  0.591695
# 3         sum_credits_100_to_500_1M           third_party_count_3M  0.553569
# 4         sum_credits_100_to_500_1M    sum_credits_lessthan_100_1M  0.556027
# 7         sum_credits_100_to_500_1M           third_party_count_6M  0.518886
# 11        sum_credits_100_to_500_1M    sum_credits_lessthan_100_6M  0.537090
# ...                             ...                            ...       ...
# 3304                 service_amt_1M                    ach_size_1M  0.584952
# 3305                 service_amt_1M              median_ach_amt_6M  0.588152
# 3307                 service_amt_1M                    ach_size_6M  0.563547
# 3309                 service_amt_1M              median_ach_amt_1M  0.589072
# 3312                 service_amt_1M    ratio_credits_grt_500_1M_6M  0.501186
#
# [1144 rows x 3 columns]
